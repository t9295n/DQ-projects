# %% [markdown]
# Earnings from college graduates. Purpose is to use basic data visualization techniques to draw conclusions from the given data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")
first_row = recent_grads.iloc[0,:]
print(first_row)
print(recent_grads.head())
print(recent_grads.tail())
print(recent_grads.describe())
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(raw_data_count)
print(cleaned_data_count)
# Out:
# 173
# 172

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter', 
                        title="Sample_size vs Median", xlim=(-100,5000))
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', 
                        title="Sample_size vs Unemployment_rate", xlim=(-100,5000))
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter', 
                     title="Full_time vs Median", xlim=(-10000,300000))
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', 
                        title="ShareWomen v Unemployment", xlim=(-0.1, 1.1), ylim=(-0.01, 0.2))
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter', 
                        title="Men vs Median", xlim=(-10000,200000))
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter', 
                        title="Women vs Median", xlim=(-10000,350000))

# %% [markdown]
# Loos like there's no correlation between the relations above. Doesn't seem like students in popular majors make more money.

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].hist()

# %%
recent_grads['Employed'].hist(bins=25)

# %%
recent_grads['Full_time'].hist(bins=25)

# %%
recent_grads['ShareWomen'].hist(bins=10)

# %%
recent_grads['Unemployment_rate'].hist()

# %%
recent_grads['Men'].hist()

# %%
recent_grads['Women'].hist()

# %% [markdown]
# Over half of majors seem to be predominantly female. Common median salary tends to be around 30-40k.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec5d383160>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec5d15ca20>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot(kind='bar', x='Major', y='ShareWomen')

# %%
recent_grads[-10:].plot(kind='bar', x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot(kind='bar', x='Major', y='Unemployment_rate')

# %%
recent_grads[-10:].plot(kind='bar', x='Major', y='Unemployment_rate')

# %%
recent_grads[:10].plot(kind='bar', x='Major', y='Median')

# %%
recent_grads[-10:].plot(kind='bar', x='Major', y='Median')

# %% [markdown]
# It seems like majors that are predominantly male (engineering) have higher median salaries.
